# %%
print("hello world")
# Out:
# hello world

# %%
for i in range(10):
    print(f"testing {i}")
# Out:
# testing 0
# testing 1
# testing 2
# testing 3
# testing 4
# testing 5
# testing 6
# testing 7
# testing 8
# testing 9

# %%
print("Third cell")
# Out:
# Third cell

# %%
print("testing matplotlib")


# importing the required module  
import matplotlib.pyplot as plt  
    
# x axis values  
x = [1,2,3]  
# corresponding y axis values  
y = [2,4,1]  
    
# plotting the points   
plt.plot(x, y)  
    
# naming the x axis  
plt.xlabel('x - axis')  
# naming the y axis  
plt.ylabel('y - axis')  
    
# giving a title to my graph  
plt.title('My first graph!')  
    
# function to show the plot  
plt.show()
# Out:
# testing matplotlib

# %%
# Open the file in read mode
with open("hello_world.txt", "r") as file:
    content = file.read()

print(content)
# Out:
# Hello, World! Testing write file, you should be able to read this message in the ipykernel.
